# %% [markdown]
# <a href="https://colab.research.google.com/github/Monikerton/mos_challenges/blob/main/RNA_Splicing_Hard_Game_Challenge_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Challenge: Decode the Mystery of mRNA!**
#
# Welcome to the "mRNA Mastermind" coding challenge! In this challenge, you are given an extremely long piece of mRNA. Your mission is to unravel its secrets using Python code. Are you ready to identify the crucial elements needed for protein creation?

# %% [markdown]
# ![mRNA_splicing_image.jpg](data:image/jpeg;base64,...)
#
# [Image Source](https://www.vecteezy.com/vector-art/9890934-diagram-showing-the-biological-process-of-rna-splicing-to-remove-intron-after-transcription-and-produce-mrna)

# %% [markdown]
# We will begin by defining a sequence that we will be treating as our pre-mRNA sequence stored in a variable called `pre_mrna`.
#
# The origin of this sequence can be found [in this genome dataset](https://www.ncbi.nlm.nih.gov/datasets/genome/GCF_000146465.1/). In the form of a fasta file. Fasta files which is a filetype used to represent biological sequence data.

# %%
pre_mrna_gene = "..."

# %% [markdown]
# To begin, we need to do some **pre-processing** on this data. Although this template defines an mRNA, one can notice that it's actually in **DNA** format! This is because the gene needs to actually be transcribed before we get an actual RNA Sequence.
#
# How would you transcribe this DNA sequence into RNA? Hint: you only need to do one thing!

# %%
pre_mrna = # write your solution here.
# Out:
#   File "<ipython-input-3-cb9eeafbe50f>", line 1
#     pre_mrna = # write your solution here.
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Task 1: **Find Start and Stop Codons**
#
# Your first task is to identify all the start codon (AUG) and stop codons (UAA, UAG, UGA) within the pre-mRNA sequence. These codons signal the beginning and end of protein synthesis.
#
# To denote the locations of these codons, give a list of the locations of the first index of each start codon and each stop codon in two separate lists: `start_codons` and `stop_codons`. In biology, everything is 1-indexed, meaning the first index in a string will be one. Make sure to ensure that your code is 1-indexed when doing this challenge!

# %%
start_codons = # write your solution here.
stop_codons = # write your solution here.
# Out:
#   File "<ipython-input-4-70781cc7b42f>", line 1
#     start_codons = # write your solution here.
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Task #2: **Locate Potential Splice Sites**
#
# [Splice donor/acceptor sites](https://bio.libretexts.org/Bookshelves/Genetics/Working_with_Molecular_Genetics_(Hardison)/Unit_III%3A_The_Pathway_of_Gene_Expression/12%3A_RNA_processing/12.6%3A_Splicing_of_introns_in_premRNAs#:~:text=The%20GU%20is%20the%205%27%20splice%20site%20%28sometimes,the%20most%20prevalent%20class%20of%20introns%20in%20pre-mRNA): In eukaryotic organisms, exons are often flanked by specific splice site sequences at the boundary of exons and introns. For example, some introns start with "GU" and end with "AG" (donor and acceptor splice sites).
#
# Search the mRNA sequence for potential splice sites with the signature GU...AG. Splice sites help the cell cut out non-coding regions (introns) and stitch together coding regions (exons).
#
# Your splice sites should be given in a list of length-two tuples. You do not need to specify nested splice sites (that is, splice sites that have other splice sites within them).

# %%
splice_sites = ## solution here

# %% [markdown]
# ## Task #3: **Identify Introns and Exons**
#
# Of course, not every sequence that takes the form GU...AG is an intron. For simplicity's sake, lets assume that only sequences greater than **20 (number can be changed) ** base pairs take this form.
#
# Using the specified splice sites, identify all possible introns (regions to be removed) and exons (coding regions to keep). Store them in two variables, `introns_list` and `exons_list`, which specify the indices of introns and exons in the list. This list should be in an ordered format.

# %%
## Your code here

# %% [markdown]
# ## Task #4: **mRNA Sequences and Protein Variants**
#
# How many possible completed, spliced mRNA sequences can be made using only exons? An mRNA sequence is considered "complete" if it contains at least one exon in the sequence.

# %%
num_variants = # Your solution here

# %% [markdown]
# ## Task #5: **Functional Protein Count**
#
# Now comes the brain-busting question: Finally, how many of the spliced mRNA sequences can actually be translated (with only exons included)?
#
# In order for an mRNA protein to be properly transcribed, there needs to be a start codon and a stop codon. The start codon tells where the mRNA needs to start, while the stop codon says where the mRNA needs to stop. We want to see how many of our exons actually specify start and stop codons.
#
# For the purposes of this question, assume we will only consider unique mRNA templates. **Return the number of sequences, and the sequences themselves** as a list of tuples.
